# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
composite_info = pd.read_csv('data/CT_composite.csv')
death_info = pd.read_csv('data/deaths_by_county.csv')
death_info
# Out:
#     Unnamed: 0 Jurisdiction  Year  ResidentDeaths  DeathsInCounty
# 0            0    Fairfield  2012              51              52
# 1            1    Fairfield  2013              83              94
# 2            2    Fairfield  2014              76              91
# 3            3    Fairfield  2015             106             103
# 4            4    Fairfield  2016             159             165
# 5            5    Fairfield  2017             147             165
# 6            6    Fairfield  2018             148             151
# 7            7     Hartford  2012              92             101
# 8            8     Hartford  2013             119             132
# 9            9     Hartford  2014             142             166
# 10          10     Hartford  2015             189             212
# 11          11     Hartford  2016             255             284
# 12          12     Hartford  2017             284             338
# 13          13     Hartford  2018             283             339
# 14          14    New Haven  2012              90              99
# 15          15    New Haven  2013             130             135
# 16          16    New Haven  2014             140             141
# 17          17    New Haven  2015             188             211
# 18          18    New Haven  2016             233             263
# 19          19    New Haven  2017             274             288
# 20          20    New Haven  2018             239             269
# 21          21   New London  2012              43              41
# 22          22   New London  2013              51              56
# 23          23   New London  2014              49              51
# 24          24   New London  2015              59              61
# 25          25   New London  2016              85              90
# 26          26   New London  2017              85              81
# 27          27   New London  2018              89              91
# 28          28   Litchfield  2012              20              17
# 29          29   Litchfield  2013              35              36
# 30          30   Litchfield  2014              41              36
# 31          31   Litchfield  2015              51              47
# 32          32   Litchfield  2016              38              29
# 33          33   Litchfield  2017              54              49
# 34          34   Litchfield  2018              69              65
# 35          35    Middlesex  2012              26              19
# 36          36    Middlesex  2013              33              17
# 37          37    Middlesex  2014              48              24
# 38          38    Middlesex  2015              64              40
# 39          39    Middlesex  2016              63              34
# 40          40    Middlesex  2017              86              45
# 41          41    Middlesex  2018              87              44
# 42          42      Windham  2012              13              14
# 43          43      Windham  2013              11               9
# 44          44      Windham  2014              21              24
# 45          45      Windham  2015              27              33
# 46          46      Windham  2016              27              27
# 47          47      Windham  2017              41              44
# 48          48      Windham  2018              36              33
# 49          49      Tolland  2012              12              12
# 50          50      Tolland  2013               9              10
# 51          51      Tolland  2014              26              25
# 52          52      Tolland  2015              25              20
# 53          53      Tolland  2016              30              25
# 54          54      Tolland  2017              30              28
# 55          55      Tolland  2018              33              26

# %%
# plot test -- to incorporate in loop
def unemployment_and_resident_deaths(county):
    df = composite_info[composite_info["Jurisdiction"] == county]
    plt.plot(df["Year"],df["ResidentDeaths"])
    plt.plot(df["Year"],df["%Unemployed"] * 10)
    plt.plot(df["Year"],df[""])

# %%
unemployment_and_resident_deaths('Middlesex')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-17097c3c9f86> in <module>
# ----> 1 unemployment_and_resident_deaths('Middlesex')
#
# <ipython-input-17-6c1751c5a7f7> in unemployment_and_resident_deaths(county)
#       4     plt.plot(df["Year"],df["ResidentDeaths"])
#       5     plt.plot(df["Year"],df["%Unemployed"] * 10)
# ----> 6     plt.plot(df["Year"],df[""])
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %%
def residentDeathsNorm():
    for jurisdiction in list(composite_info["Jurisdiction"].unique()):
        df = composite_info[composite_info["Jurisdiction"] == jurisdiction]
        plt.plot(df["Year"], df["ResidentDeathsNorm"] / df["unempNorm"], label=jurisdiction)
    plt.legend()

# %%
residentDeathsNorm()

# %%
def deathsInCountyNorm():
    for jurisdiction in list(composite_info["Jurisdiction"].unique()):
        df = composite_info[composite_info["Jurisdiction"] == jurisdiction]
        plt.plot(df["Year"], df["DeathsInCountyNorm"])

# %%
deathsInCountyNorm()
