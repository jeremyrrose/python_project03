# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
composite_info = pd.read_csv('data/CT_composite.csv')
death_info = pd.read_csv('data/deaths_by_county.csv')

# %%
# plot test -- to incorporate in loop
def unemployment_and_resident_deaths(county):
    df = composite_info[composite_info["Jurisdiction"] == county]
    plt.plot(df["Year"],df["ResidentDeathsNorm"], label="Per Cap Resident Deaths")
    plt.plot(df["Year"],df["unempNorm"], label="Unemployment")
    plt.title(county)
    plt.legend()
    plt.show()

# %%
def unemp_res_deaths_all():
    for jurisdiction in list(composite_info["Jurisdiction"].unique()):
        if jurisdiction != "Connecticut":
            unemployment_and_resident_deaths(jurisdiction)
        
unemp_res_deaths_all()

# %%
def residentDeathsNorm():
    for jurisdiction in list(composite_info["Jurisdiction"].unique()):
        df = composite_info[composite_info["Jurisdiction"] == jurisdiction]
        plt.plot(df["Year"], df["ResidentDeathsNorm"] / df["unempNorm"], label=jurisdiction)
    plt.legend()

# %%
residentDeathsNorm()

# %%
def deathsInCountyNorm():
    for jurisdiction in list(composite_info["Jurisdiction"].unique()):
        df = composite_info[composite_info["Jurisdiction"] == jurisdiction]
        plt.plot(df["Year"], df["DeathsInCountyNorm"])

# %%
deathsInCountyNorm()

# %%
composite_info
# Out:
#     Unnamed: 0 Jurisdiction  Year  MedianHouseholdIncome  %inPoverty  \
# 0            0  Connecticut  2012                  67275        10.6
# 1            1    Fairfield  2012                  79536         8.9
# 2            2     Hartford  2012                  63374        12.2
# 3            3   Litchfield  2012                  67746         7.0
# 4            4    Middlesex  2012                  74588         6.4
# ..         ...          ...   ...                    ...         ...
# 58          58    Middlesex  2018                  88709         6.7
# 59          59    New Haven  2018                  67720        11.6
# 60          60   New London  2018                  67790         9.8
# 61          61      Tolland  2018                  89584         8.0
# 62          62      Windham  2018                  65182        11.7
#
#     TotalInPoverty  %MinorsInPoverty  TotalMinorsInPoverty  %Unemployed  \
# 0           370537              14.6                114613     8.349387
# 1            81756              11.1                 24854     7.800000
# 2           106357              16.7                 32889     8.500000
# 3            12975               8.6                  3272     7.600000
# 4            10376               7.5                  2470     7.200000
# ..             ...               ...                   ...          ...
# 58           10556               8.1                  2314     3.500000
# 59           96563              16.7                 28530     4.400000
# 60           25063              12.5                  6388     4.000000
# 61           10835               6.4                  1652     3.600000
# 62           13135              14.8                  3351     4.600000
#
#     Population  povNorm  povMinorsNorm  unempNorm  DeathsInCounty  \
# 0      3594547      100            100        100           352.0
# 1       935099       83             76         93            51.0
# 2       897706      115            114        101           101.0
# 3       187570       66             58         91            17.0
# 4       165634       60             51         86            18.0
# ..         ...      ...            ...        ...             ...
# 58      162870       65             58         84            44.0
# 59      856971      112            121        106           267.0
# 60      266285       95             90         96            90.0
# 61      150689       77             46         86            26.0
# 62      117059      113            107        110            33.0
#
#     ResidentDeaths  PerCapDeathsInCounty  PerCapResidentDeaths  \
# 0            328.0              0.000098              0.000091
# 1             50.0              0.000055              0.000053
# 2             89.0              0.000113              0.000099
# 3             18.0              0.000091              0.000096
# 4             20.0              0.000109              0.000121
# ..             ...                   ...                   ...
# 58            51.0              0.000270              0.000313
# 59           235.0              0.000312              0.000274
# 60            88.0              0.000338              0.000330
# 61            32.0              0.000173              0.000212
# 62            36.0              0.000282              0.000308
#
#     DeathsInCountyNorm  ResidentDeathsNorm
# 0           100.000000          100.000000
# 1            55.694728           58.597992
# 2           114.891725          108.649117
# 3            92.552264          105.166991
# 4           110.974838          132.327720
# ..                 ...                 ...
# 58           95.247859          119.101320
# 59          109.847146          104.301182
# 60          119.162456          125.696581
# 61           60.832468           80.771086
# 62           99.392307          116.972881
#
# [63 rows x 19 columns]
