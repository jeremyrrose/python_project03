# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
economic_info = pd.read_csv('data/CT_composite.csv')
death_info = pd.read_csv('data/deaths_by_county.csv')
death_info
# Out:
#     Unnamed: 0 Jurisdiction  Year  ResidentDeaths  DeathsInCounty
# 0            0    Fairfield  2012              50              51
# 1            1    Fairfield  2013              78              94
# 2            2    Fairfield  2014               0              62
# 3            3    Fairfield  2015             103             102
# 4            4    Fairfield  2016             158               0
# 5            5    Fairfield  2017             144             163
# 6            6    Fairfield  2018             147             151
# 7            7     Hartford  2012              89             101
# 8            8     Hartford  2013             114             132
# 9            9     Hartford  2014               0             118
# 10          10     Hartford  2015             182             210
# 11          11     Hartford  2016             255               0
# 12          12     Hartford  2017             283             335
# ...

# %%
# plot test -- to incorporate in loop

econ = economic_info[economic_info["Jurisdiction"] == "Fairfield"]
deaths = death_info[death_info["Jurisdiction"] == "Fairfield"]

# %%
plt.plot(deaths["Year"],deaths["ResidentDeaths"])
plt.plot(econ["Year"],econ["%Unemployed"] / econ[econ.Jurisdiction] )
